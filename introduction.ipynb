# %% [markdown]
# <a href="https://colab.research.google.com/github/Gibbons-Lab/2021_data_literacy/blob/main/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Notebooks and Colaboratory

# %% [markdown]
# ## Code Notebooks: What and Why?
#
# Hi and welcome! A large part of Science but also Companies those days rely on analyzing data in more and more complex ways. But how do they actually do that? In some cases they might use some premade tool such as Excel but in many cases we need something a bit more flexible. Spreadsheets might be fine for some simple analysis and figures but if you want to train a speech recognition Artifical Intelligence model this won't be possible in Spreadsheets anymore.
#
# So what do we use instead? You might have heard already that this is usually done with "code" and "computer programming" but if you work together with other researchers or colleagues just using some hard to understand code is usually not sufficient. You also need to explain what and you did and why so somebody else can pick up where you left off. Think about a wet lab. If you did an experiment to isolate some DNA and would like your colleague to do something similar, what would you do? Exactly, you would write a protocol. And interactive notebooks are pretty much that: protocols for Computer Science.
#
# There is one small and very cool difference though: the notebooks are actually interactive and can execute the code as well. So they are kind of like something from Harry Potter, an instruction book that will actually perform the things you want while reading it 🧙. So how does that work?
#
# ![Harry Potter clapping](https://thumbs.gfycat.com/EachDeterminedAmurminnow-size_restricted.gif)
#
# Well, notebooks on colaboratory are basically just text documents that connect with the cloud. Here, "cloud" just means somebody else's computer, in this case a Google Server. The document is organized into small blocks called "cells" and each cell either contains text, code, or some code output. This way you can mix the protocol and the actual code running an analysis. The cell containing this very text is obviously a text cell and if you would double-click on it you basically get a small text editor that let's you change the text. You can use Shift+Enter to "render" the text which will just print it to the protocol. For instance try to fill in the "?" in the following section.
#
# 🐭 = mouse
#
# 🐶 = ?

# %% [markdown]
# ## Code Cells
#
# The cell underneath is a code cell, meaning that it can execute computer code. In particular, this notebook uses the programming language [Python](https://www.python.org/) which is a beginner-friendly but also super-powerful programming language. For instance, it runs a large part of Amazon and Google. If you type valid code in the cell and push the little play button next to it it will execute the code. For instance, we can use that to calculate the number of seconds in a year:

# %%
365 * 24 * 60 * 60
# Out:
# 31536000

# %% [markdown]
# Nice! You could do about anything you can possibly imagine here but you would parobably need to to pick up some programming experience with Python for that. However, for now we will limit ourselves to running some existing code and modifying it and we will only pick up some basic Python lingo here.
#
# # 3 concepts to understand code
#
# So coding can be complex, but we can get pretty far by only looking at three concepts here.

# %% [markdown]
# ## Variables
#
# Variables are placeholders for some specifc value just like in math. We can assign values to variables with `=`. To asign text to a variable we have to wrap it in `"` or `'` (either one is fine but don't mix them).

# %%
x = 3
x + 2
# Out:
# 5

# %%
greeting = "Hello"
name = "Marie"

greeting + " " + name
# Out:
# 'Hello Marie'

# %% [markdown]
# ## Functions
#
# Functions are a way to tell a computer to actually do something and they take arguments that tell them how to do something. They are named and used  by writing the function name followed by a list of argument in brackets. So for instance if your function is called `make_sandwich` and you want to tell it to use ham, chhese and lettuce, you would write `make_sandwich(ham, cheese, lettuce)`. The arguments can also be named and in this case the function is called like `make_sandwich(protein=ham, dairy=cheese, veggie=lettuce)`.
#
# For instance, one function in Python is `max` that will return the maximum value of all it's arguments.

# %%
max(1, 3, 2, 9, 7)
# Out:
# 9

# %% [markdown]
# ## Libraries
#
# Libraries are collections of functions. To use a library we have to import it and give it a name or import single functions directly from it. If we named the library we can use the functions by prefixing them with the library name and a period. If we imported specific functions we can use them without any prefix. Let's see how that works by importing the function `log` from the library `numpy` which can calculate the natural logarithm of a number.

# %%
import numpy as np

np.log(2.3)
# Out:
# 0.8329091229351039

# %%
from numpy import log

log(2.3)
# Out:
# 0.8329091229351039

# %% [markdown]
# The colaboratory notebook comes with *a lot* of pre-installed libraries that can help you do everything that Excel does and then some. And yes, you could even train a speech recognition model right here in this very notebook if you wanted 🤯
#
# For now let's look at some more interesting examples. We will look at some functions in a library called `seaborn` which can make sophisticated figures from data, so somewhat similar to the charts in spreadsheets.
#
# # Penguins and Islands
#
# We will import the library and name it "sns" so we have to type less. Then we will use a function called `load_dataset` to load a table of measurements of different penguins and assign that to a variable called "pengu" to use it later.

# %%
import seaborn as sns

pengu = sns.load_dataset("penguins")
pengu
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# ...

# %% [markdown]
# As you can see this has data for 344 penguins like their species, where they live, body measurements and their sex.
#
# *BTW, "bill" is the name for a penguin's beak.*
#
# We might expect that heavier penguins have longer flippers. To see if that is true we might want to plot the weight against the flipper length. This can be done using the `scatterplot` function from seaborn.

# %%
sns.scatterplot(x="body_mass_g", y="flipper_length_mm", data=pengu)

# %% [markdown]
# Cool, that shows that our hypothesis seems to be correct. But what about different islands? Let's also color the points by the island each penguin came from.

# %%
sns.scatterplot(x="body_mass_g", y="flipper_length_mm", hue="island", data=pengu)

# %% [markdown]
# Okay, looks like our hypothesis still works but the Biscoe island definitely has larger penguins than the other two islands.

# %% [markdown]
# So weight and flipper length are definitely correlated but we can also check that with math by calculating the correlation coefficients. Turns out that our `pengu` dataset comes with its own set of functions. One of them is called `corr` and calculates the Pearson correlation coefficients between all pairs of columns in the data.

# %%
pengu.corr()
# Out:
#                    bill_length_mm  ...  body_mass_g
# bill_length_mm           1.000000  ...     0.595110
# bill_depth_mm           -0.235053  ...    -0.471916
# flipper_length_mm        0.656181  ...     0.871202
# body_mass_g              0.595110  ...     1.000000
#
# [4 rows x 4 columns]

# %% [markdown]
# From that we can see that weight and flipper length are positively correlated. We can even fit lines to the data in the plot. For that, we only have to substitute the `scatterplot` functions with the `lmplot` function (short for "linear model plot"). Lets also make the plot a bit larger by using the `height` argument.

# %%
sns.lmplot(x="body_mass_g", y="flipper_length_mm", hue="island", data=pengu, height=10)

# %% [markdown]
# The plot now shows linear regression lines for each island. The shaded areas denote standard error of the line (the uncertainty associated with the linear model). As we can see the slope of the line is a bit steeper for the Biscoe island, meaning that the penguins there have longer flippers for a particular weight compared to the other two islands. Pretty neat, right?
#
# And that's only the tip of the iceberg of what you can do with seaborn. You can check out the [documentation](https://seaborn.pydata.org/index.html) if you want to learn more.
